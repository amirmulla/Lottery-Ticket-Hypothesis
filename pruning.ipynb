# %% [markdown]
# <a href="https://colab.research.google.com/github/amirmulla/Lottery-Ticket-Hypothesis/blob/main/pruning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
###########################
# Mount Google Drive      #
###########################

from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
results_dir = '/content/drive/MyDrive/Deep Learning Project/Results'
model_dir = '/content/drive/MyDrive/Deep Learning Project/Models'
# Out:
# Mounted at /content/drive/

# %%
import torch
from torch import nn
import torch.nn.utils.prune as prune
import numpy as np
from torch import optim
import time

from torchvision import datasets, transforms
from torch.utils.data.sampler import SubsetRandomSampler
import helper

# number of subprocesses to use for data loading
num_workers = 0
# how many samples per batch to load
batch_size = 20

# convert data to torch.FloatTensor
transform = transforms.ToTensor()

# choose the training and test datasets
train_data = datasets.MNIST(root='data', train=True, download=True, transform=transform)
test_data = datasets.MNIST(root='data', train=False, download=True, transform=transform)

# prepare data loaders
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, num_workers=num_workers)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size, num_workers=num_workers)

# %%
# define the NN architecture
class LeNet(nn.Module):
    def __init__(self, int_range=0.5):
        super(LeNet, self).__init__()
        # number of hidden nodes in each layer
        hidden_1 = 300
        hidden_2 = 100
        # linear layer (784 -> hidden_1)
        self.fc1 = nn.Linear(28 * 28, hidden_1)
        # linear layer (n_hidden -> hidden_2)
        self.fc2 = nn.Linear(hidden_1, hidden_2)
        # linear layer (n_hidden -> 10)
        self.fc3 = nn.Linear(hidden_2, 10)
        # dropout layer (p=0.2)
        # dropout prevents overfitting of data
        self.dropout = nn.Dropout(0.2)
        # activation
        self.activation = nn.ReLU()

    def forward(self, x):
        # flatten image input
        x = x.view(-1, 28 * 28)
        # add hidden layer, with relu activation function
        x = self.activation(self.fc1(x))
        # add dropout layer
        x = self.dropout(x)
        # add hidden layer, with relu activation function
        x = self.activation(self.fc2(x))
        # add dropout layer
        x = self.dropout(x)
        # add output layer
        x = self.fc3(x)
        return x

# initialize the NN
model = LeNet()
print(model)
# Out:
# LeNet(
#   (fc1): Linear(in_features=784, out_features=300, bias=True)
#   (fc2): Linear(in_features=300, out_features=100, bias=True)
#   (fc3): Linear(in_features=100, out_features=10, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (activation): ReLU()
# )

# %%
###########################
# Model Evaluation        #
###########################

def eval_model(model, criterion, loader):
    running_loss = 0.0
    class_correct = list(0. for i in range(10))
    class_total = list(0. for i in range(10))    

    for data, target in loader:
        data, target = data.cuda(), target.cuda()
        output = model(data)
        loss = criterion(output, target)
        running_loss += loss.item()*data.size(0)
        _, pred = torch.max(output, 1)
        correct = np.squeeze(pred.eq(target.data.view_as(pred)))
        for i in range(len(target)):
            label = target.data[i]
            class_correct[label] += correct[i].item()
            class_total[label] += 1

    out_loss = running_loss/len(loader.sampler)
    out_acc = np.sum(class_correct) / np.sum(class_total)

    return out_loss, out_acc

###########################
# Model Training          #
###########################

def train_model(model, model_name, epochs = 20, lr=0.001):      
    model_res_path = results_dir + '/' + model_name + '.pt'
    model_name = model_dir + '/' + model_name + '.pt'
    print(model_name)
    
    model.cuda()

    # Define the loss and optimizer
    criterion = nn.CrossEntropyLoss().cuda()
    optimizer = optim.Adam(model.parameters(), lr=lr)

    train_loss_list = list(0. for i in range(epochs))
    test_loss_list = list(0. for i in range(epochs))
    train_acc_list = list(0. for i in range(epochs))
    test_acc_list = list(0. for i in range(epochs)) 

    test_loss_min = np.Inf

    for epoch in range(epochs):
        t0 = time.time()

        # Train the model
        model.train()
        for images, labels in train_loader:
            images, labels = images.cuda(), labels.cuda()       
            optimizer.zero_grad()
            output = model(images)
            loss = criterion(output, labels)
            loss.backward()
            optimizer.step()

        # Evaluate the model
        model.eval()
        with torch.no_grad():
            train_loss, train_acc = eval_model(model, criterion, train_loader)
            test_loss, test_acc = eval_model(model, criterion, test_loader)             

        print('Epoch: {} ({:.2f} seconds) Train Loss: {:.6f} Train Accuracy: {:.6f} Test Loss: {:.6f} Test Accuracy: {:.6f}'
        .format(epoch+1,time.time()-t0, train_loss, train_acc, test_loss, test_acc))
        
        # Save model if validation loss has decreased
        if test_loss <= test_loss_min:
          print('Test loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(test_loss_min,test_loss))
          torch.save(model.state_dict(), model_name)
          test_loss_min = test_loss

        train_loss_list[epoch] = train_loss
        test_loss_list[epoch] = test_loss
        train_acc_list[epoch] = train_acc
        test_acc_list[epoch] = test_acc
    
    acc_tesor_dict = {'train_loss': torch.tensor(train_loss_list),
                      'test_loss': torch.tensor(test_loss_list),
                      'train_acc': torch.tensor(train_acc_list),
                      'test_acc': torch.tensor(test_acc_list)}    

    print('Saving...')
    torch.save(acc_tesor_dict, model_res_path)
    print('Saved')

# %%
######################################
# Pruning functions.                 #
######################################

def random_init_model(model, init_range=0.5):
  init_params = []
  for name, param in model.named_parameters():
    param.data.uniform_(-init_range, init_range)
    init_params.append(param.data.clone())

  return init_params

def rewind_model_params(model, init_params):
  i = 0
  for _ , param in model.named_parameters():
    param.data = init_params[i].clone()
    i+=1

def prune_init_model(model):
  for layer in model.children():
    if isinstance(layer, nn.Linear):
      prune.identity(layer, name='weight')

def prune_model(model, prune_ratio=0.2, prune_method='l1_unstructured'):
  for layer in model.children():
    if isinstance(layer, nn.Linear):
      prune.l1_unstructured(layer, name='weight', amount=prune_ratio)

# %%
def calc_model_sparsity(model):
  zero_weights = 0.0
  n_elements = 0.0
  for layer in model.children():
    if isinstance(layer, nn.Linear):
      zero_weights += torch.sum(layer.weight == 0)
      n_elements += layer.weight.nelement()

  return (100.* zero_weights/ n_elements)

def print_sparsity(model):
  print("Model sparsity: {:.2f}%".format(calc_model_sparsity(model)))

# %%
##############################
# Run                        #
##############################
epochs = 30
lr = 0.01
batch_size = 64
prune_ratio = 0.85
rounds = 1

model = LeNet()
prune_init_model(model)
init_params = random_init_model(model)

print('Train and evaluate lenet model with Pruning:')

for round in range(rounds):
  print('Start prune round: {}'.format(round+1))
  t0 = time.time()
  train_model(model, 'model_lenet', epochs=epochs, lr=lr)
  prune_model(model, prune_ratio)
  print_sparsity(model)
  random_init_model(model)
  train_model(model, 'model_prune_lenet_random_init', epochs=epochs, lr=lr)
  rewind_model_params(model, init_params)
  train_model(model, 'model_prune_lenet_rewind_init', epochs=epochs, lr=lr)

print('Final Training:')
t0 = time.time()
train_model(model, 'model_prune_lenet', epochs=epochs, lr=lr)

print(f'lenet model, took {time.time()-t0: .2f} seconds')
# Out:
# Train and evaluate lenet model with Pruning:
# Start prune round: 1
# /content/drive/MyDrive/Deep Learning Project/Models/model_lenet.pt
# Epoch: 1 (23.67 seconds) Train Loss: 0.358376 Train Accuracy: 0.895300 Test Loss: 0.356828 Test Accuracy: 0.898400
# Test loss decreased (inf --> 0.356828).  Saving model ...
# Epoch: 2 (23.81 seconds) Train Loss: 0.275444 Train Accuracy: 0.927333 Test Loss: 0.271646 Test Accuracy: 0.930900
# Test loss decreased (0.356828 --> 0.271646).  Saving model ...
# Epoch: 3 (23.09 seconds) Train Loss: 0.291970 Train Accuracy: 0.942300 Test Loss: 0.356526 Test Accuracy: 0.938000
# Epoch: 4 (23.59 seconds) Train Loss: 0.260035 Train Accuracy: 0.943317 Test Loss: 0.321230 Test Accuracy: 0.941900
# Epoch: 5 (23.79 seconds) Train Loss: 0.220122 Train Accuracy: 0.944017 Test Loss: 0.263843 Test Accuracy: 0.942300
# Test loss decreased (0.271646 --> 0.263843).  Saving model ...
# Epoch: 6 (23.67 seconds) Train Loss: 0.268574 Train Accuracy: 0.943750 Test Loss: 0.388325 Test Accuracy: 0.940900
# Epoch: 7 (23.99 seconds) Train Loss: 0.249072 Train Accuracy: 0.948217 Test Loss: 0.357503 Test Accuracy: 0.945000
# Epoch: 8 (23.55 seconds) Train Loss: 0.287445 Train Accuracy: 0.942250 Test Loss: 0.366595 Test Accuracy: 0.934200
# Epoch: 9 (24.07 seconds) Train Loss: 0.219707 Train Accuracy: 0.942400 Test Loss: 0.343548 Test Accuracy: 0.935900
# Epoch: 10 (23.47 seconds) Train Loss: 0.232315 Train Accuracy: 0.940817 Test Loss: 0.358636 Test Accuracy: 0.937300
# Epoch: 11 (23.62 seconds) Train Loss: 0.281545 Train Accuracy: 0.935617 Test Loss: 0.427696 Test Accuracy: 0.931300
# Epoch: 12 (24.19 seconds) Train Loss: 0.215121 Train Accuracy: 0.944117 Test Loss: 0.326141 Test Accuracy: 0.936700
# Epoch: 13 (25.02 seconds) Train Loss: 0.227366 Train Accuracy: 0.941717 Test Loss: 0.458642 Test Accuracy: 0.934300
# Epoch: 14 (24.43 seconds) Train Loss: 0.244190 Train Accuracy: 0.933567 Test Loss: 0.436291 Test Accuracy: 0.926600
# Epoch: 15 (23.31 seconds) Train Loss: 0.226160 Train Accuracy: 0.946050 Test Loss: 0.436459 Test Accuracy: 0.943900
# Epoch: 16 (24.02 seconds) Train Loss: 0.220232 Train Accuracy: 0.950250 Test Loss: 0.428588 Test Accuracy: 0.939800
# Epoch: 17 (23.20 seconds) Train Loss: 0.195235 Train Accuracy: 0.954900 Test Loss: 0.455762 Test Accuracy: 0.945900
# Epoch: 18 (22.85 seconds) Train Loss: 0.256245 Train Accuracy: 0.935517 Test Loss: 0.458433 Test Accuracy: 0.928100
# Epoch: 19 (23.56 seconds) Train Loss: 0.241636 Train Accuracy: 0.937317 Test Loss: 0.437207 Test Accuracy: 0.935600
# Epoch: 20 (23.12 seconds) Train Loss: 0.236879 Train Accuracy: 0.939933 Test Loss: 0.487888 Test Accuracy: 0.932100
# Epoch: 21 (23.62 seconds) Train Loss: 0.220723 Train Accuracy: 0.933367 Test Loss: 0.434899 Test Accuracy: 0.931400
# Epoch: 22 (23.88 seconds) Train Loss: 0.221243 Train Accuracy: 0.936467 Test Loss: 0.422362 Test Accuracy: 0.928800
# Epoch: 23 (23.95 seconds) Train Loss: 0.208822 Train Accuracy: 0.938400 Test Loss: 0.389231 Test Accuracy: 0.932400
# Epoch: 24 (23.63 seconds) Train Loss: 0.314126 Train Accuracy: 0.933717 Test Loss: 0.714289 Test Accuracy: 0.928400
# Epoch: 25 (23.48 seconds) Train Loss: 0.233060 Train Accuracy: 0.922433 Test Loss: 0.434737 Test Accuracy: 0.916900
# Epoch: 26 (23.71 seconds) Train Loss: 0.204755 Train Accuracy: 0.943217 Test Loss: 0.588293 Test Accuracy: 0.937200
# Epoch: 27 (23.96 seconds) Train Loss: 0.225818 Train Accuracy: 0.939267 Test Loss: 0.619765 Test Accuracy: 0.931900
# Epoch: 28 (23.61 seconds) Train Loss: 0.261125 Train Accuracy: 0.933483 Test Loss: 0.667375 Test Accuracy: 0.929700
# Epoch: 29 (23.75 seconds) Train Loss: 0.201961 Train Accuracy: 0.942117 Test Loss: 0.641248 Test Accuracy: 0.932300
# Epoch: 30 (23.78 seconds) Train Loss: 0.219918 Train Accuracy: 0.936250 Test Loss: 0.833670 Test Accuracy: 0.928300
# Saving...
# Saved
# Model sparsity: 85.00%
# /content/drive/MyDrive/Deep Learning Project/Models/model_prune_lenet_random_init.pt
# Epoch: 1 (22.98 seconds) Train Loss: 0.213953 Train Accuracy: 0.939350 Test Loss: 0.213479 Test Accuracy: 0.938200
# Test loss decreased (inf --> 0.213479).  Saving model ...
# Epoch: 2 (23.85 seconds) Train Loss: 0.159076 Train Accuracy: 0.949900 Test Loss: 0.179483 Test Accuracy: 0.946700
# Test loss decreased (0.213479 --> 0.179483).  Saving model ...
# Epoch: 3 (23.67 seconds) Train Loss: 0.139821 Train Accuracy: 0.960300 Test Loss: 0.175491 Test Accuracy: 0.953400
# Test loss decreased (0.179483 --> 0.175491).  Saving model ...
# Epoch: 4 (22.93 seconds) Train Loss: 0.122143 Train Accuracy: 0.962017 Test Loss: 0.156409 Test Accuracy: 0.955800
# Test loss decreased (0.175491 --> 0.156409).  Saving model ...
# Epoch: 5 (23.33 seconds) Train Loss: 0.135616 Train Accuracy: 0.957617 Test Loss: 0.174421 Test Accuracy: 0.955200
# Epoch: 6 (23.71 seconds) Train Loss: 0.112638 Train Accuracy: 0.966750 Test Loss: 0.189385 Test Accuracy: 0.958900
# Epoch: 7 (23.61 seconds) Train Loss: 0.096363 Train Accuracy: 0.969017 Test Loss: 0.156664 Test Accuracy: 0.960100
# Epoch: 8 (24.40 seconds) Train Loss: 0.092102 Train Accuracy: 0.972200 Test Loss: 0.166087 Test Accuracy: 0.963700
# Epoch: 9 (23.84 seconds) Train Loss: 0.099736 Train Accuracy: 0.971317 Test Loss: 0.177425 Test Accuracy: 0.960900
# Epoch: 10 (23.50 seconds) Train Loss: 0.089484 Train Accuracy: 0.972900 Test Loss: 0.169245 Test Accuracy: 0.963400
# Epoch: 11 (23.06 seconds) Train Loss: 0.102593 Train Accuracy: 0.972933 Test Loss: 0.187493 Test Accuracy: 0.964000
# Epoch: 12 (24.31 seconds) Train Loss: 0.099388 Train Accuracy: 0.971667 Test Loss: 0.206292 Test Accuracy: 0.959300
# Epoch: 13 (23.74 seconds) Train Loss: 0.083733 Train Accuracy: 0.976767 Test Loss: 0.181866 Test Accuracy: 0.966100
# Epoch: 14 (23.13 seconds) Train Loss: 0.072377 Train Accuracy: 0.977967 Test Loss: 0.184654 Test Accuracy: 0.966400
# Epoch: 15 (24.25 seconds) Train Loss: 0.073100 Train Accuracy: 0.977567 Test Loss: 0.178083 Test Accuracy: 0.963100
# Epoch: 16 (23.67 seconds) Train Loss: 0.074095 Train Accuracy: 0.976950 Test Loss: 0.166448 Test Accuracy: 0.965400
# Epoch: 17 (23.87 seconds) Train Loss: 0.072284 Train Accuracy: 0.978450 Test Loss: 0.193410 Test Accuracy: 0.966400
# Epoch: 18 (23.51 seconds) Train Loss: 0.062081 Train Accuracy: 0.982033 Test Loss: 0.173165 Test Accuracy: 0.967500
# Epoch: 19 (23.23 seconds) Train Loss: 0.061471 Train Accuracy: 0.981100 Test Loss: 0.181983 Test Accuracy: 0.967800
# Epoch: 20 (24.11 seconds) Train Loss: 0.075498 Train Accuracy: 0.979033 Test Loss: 0.205528 Test Accuracy: 0.966600
# Epoch: 21 (23.84 seconds) Train Loss: 0.066907 Train Accuracy: 0.980600 Test Loss: 0.197246 Test Accuracy: 0.967100
# Epoch: 22 (23.31 seconds) Train Loss: 0.072422 Train Accuracy: 0.979267 Test Loss: 0.208050 Test Accuracy: 0.966600
# Epoch: 23 (23.44 seconds) Train Loss: 0.063299 Train Accuracy: 0.979900 Test Loss: 0.222116 Test Accuracy: 0.965000
# Epoch: 24 (24.99 seconds) Train Loss: 0.055875 Train Accuracy: 0.984450 Test Loss: 0.225920 Test Accuracy: 0.967900
# Epoch: 25 (23.89 seconds) Train Loss: 0.052617 Train Accuracy: 0.983417 Test Loss: 0.208182 Test Accuracy: 0.966800
# Epoch: 26 (23.52 seconds) Train Loss: 0.065809 Train Accuracy: 0.981817 Test Loss: 0.221798 Test Accuracy: 0.968100
# Epoch: 27 (24.10 seconds) Train Loss: 0.063718 Train Accuracy: 0.980400 Test Loss: 0.241506 Test Accuracy: 0.964700
# Epoch: 28 (23.85 seconds) Train Loss: 0.070042 Train Accuracy: 0.981767 Test Loss: 0.245533 Test Accuracy: 0.966200
# Epoch: 29 (23.10 seconds) Train Loss: 0.051698 Train Accuracy: 0.983200 Test Loss: 0.254217 Test Accuracy: 0.966300
# Epoch: 30 (23.35 seconds) Train Loss: 0.057666 Train Accuracy: 0.983983 Test Loss: 0.266420 Test Accuracy: 0.968200
# Saving...
# Saved
# /content/drive/MyDrive/Deep Learning Project/Models/model_prune_lenet_rewind_init.pt
# Epoch: 1 (23.73 seconds) Train Loss: 0.224663 Train Accuracy: 0.933600 Test Loss: 0.246453 Test Accuracy: 0.929000
# Test loss decreased (inf --> 0.246453).  Saving model ...
# Epoch: 2 (24.41 seconds) Train Loss: 0.139180 Train Accuracy: 0.956700 Test Loss: 0.154945 Test Accuracy: 0.954400
# Test loss decreased (0.246453 --> 0.154945).  Saving model ...
# Epoch: 3 (23.83 seconds) Train Loss: 0.129685 Train Accuracy: 0.962883 Test Loss: 0.159803 Test Accuracy: 0.958800
# Epoch: 4 (23.79 seconds) Train Loss: 0.105159 Train Accuracy: 0.968917 Test Loss: 0.138404 Test Accuracy: 0.963400
# Test loss decreased (0.154945 --> 0.138404).  Saving model ...
# Epoch: 5 (22.91 seconds) Train Loss: 0.104525 Train Accuracy: 0.969750 Test Loss: 0.156123 Test Accuracy: 0.962600
# Epoch: 6 (24.38 seconds) Train Loss: 0.100381 Train Accuracy: 0.968000 Test Loss: 0.158558 Test Accuracy: 0.957100
# Epoch: 7 (24.16 seconds) Train Loss: 0.090983 Train Accuracy: 0.973617 Test Loss: 0.157995 Test Accuracy: 0.966700
# Epoch: 8 (23.70 seconds) Train Loss: 0.087813 Train Accuracy: 0.972183 Test Loss: 0.170739 Test Accuracy: 0.965600
# Epoch: 9 (24.16 seconds) Train Loss: 0.083603 Train Accuracy: 0.975417 Test Loss: 0.165551 Test Accuracy: 0.968100
# Epoch: 10 (23.74 seconds) Train Loss: 0.082050 Train Accuracy: 0.976700 Test Loss: 0.184899 Test Accuracy: 0.963800
# Epoch: 11 (24.36 seconds) Train Loss: 0.070376 Train Accuracy: 0.979983 Test Loss: 0.160456 Test Accuracy: 0.969500
# Epoch: 12 (23.64 seconds) Train Loss: 0.078900 Train Accuracy: 0.978133 Test Loss: 0.183296 Test Accuracy: 0.968500
# Epoch: 13 (23.79 seconds) Train Loss: 0.059809 Train Accuracy: 0.980933 Test Loss: 0.154780 Test Accuracy: 0.971300
# Epoch: 14 (24.23 seconds) Train Loss: 0.064697 Train Accuracy: 0.981067 Test Loss: 0.169721 Test Accuracy: 0.968800
# Epoch: 15 (24.11 seconds) Train Loss: 0.071209 Train Accuracy: 0.979717 Test Loss: 0.177983 Test Accuracy: 0.966400
# Epoch: 16 (24.24 seconds) Train Loss: 0.052737 Train Accuracy: 0.983133 Test Loss: 0.163116 Test Accuracy: 0.970500
# Epoch: 17 (23.28 seconds) Train Loss: 0.071785 Train Accuracy: 0.980367 Test Loss: 0.189543 Test Accuracy: 0.968300
# Epoch: 18 (23.64 seconds) Train Loss: 0.053680 Train Accuracy: 0.982883 Test Loss: 0.179048 Test Accuracy: 0.970700
# Epoch: 19 (24.61 seconds) Train Loss: 0.058872 Train Accuracy: 0.981750 Test Loss: 0.179462 Test Accuracy: 0.967800
# Epoch: 20 (24.09 seconds) Train Loss: 0.054114 Train Accuracy: 0.983317 Test Loss: 0.190766 Test Accuracy: 0.971600
# Epoch: 21 (24.30 seconds) Train Loss: 0.049245 Train Accuracy: 0.984433 Test Loss: 0.200544 Test Accuracy: 0.971900
# Epoch: 22 (23.88 seconds) Train Loss: 0.050702 Train Accuracy: 0.984550 Test Loss: 0.191208 Test Accuracy: 0.970700
# Epoch: 23 (24.11 seconds) Train Loss: 0.051145 Train Accuracy: 0.983867 Test Loss: 0.216560 Test Accuracy: 0.970500
# Epoch: 24 (24.19 seconds) Train Loss: 0.046663 Train Accuracy: 0.984783 Test Loss: 0.231160 Test Accuracy: 0.969500
# Epoch: 25 (23.90 seconds) Train Loss: 0.052897 Train Accuracy: 0.985067 Test Loss: 0.191106 Test Accuracy: 0.970400
# Epoch: 26 (22.94 seconds) Train Loss: 0.049465 Train Accuracy: 0.984433 Test Loss: 0.218451 Test Accuracy: 0.970000
# Epoch: 27 (23.80 seconds) Train Loss: 0.047358 Train Accuracy: 0.985800 Test Loss: 0.235336 Test Accuracy: 0.971700
# Epoch: 28 (23.50 seconds) Train Loss: 0.042546 Train Accuracy: 0.986483 Test Loss: 0.218067 Test Accuracy: 0.970300
# Epoch: 29 (23.84 seconds) Train Loss: 0.049413 Train Accuracy: 0.985750 Test Loss: 0.221787 Test Accuracy: 0.971200
# Epoch: 30 (23.40 seconds) Train Loss: 0.051344 Train Accuracy: 0.983117 Test Loss: 0.217139 Test Accuracy: 0.967100
# Saving...
# Saved
# Final Training:
# /content/drive/MyDrive/Deep Learning Project/Models/model_prune_lenet.pt
# Epoch: 1 (23.98 seconds) Train Loss: 0.048888 Train Accuracy: 0.984500 Test Loss: 0.246423 Test Accuracy: 0.971100
# Test loss decreased (inf --> 0.246423).  Saving model ...
# Epoch: 2 (23.65 seconds) Train Loss: 0.049052 Train Accuracy: 0.985517 Test Loss: 0.210117 Test Accuracy: 0.971300
# Test loss decreased (0.246423 --> 0.210117).  Saving model ...
# Epoch: 3 (22.98 seconds) Train Loss: 0.048697 Train Accuracy: 0.985950 Test Loss: 0.246492 Test Accuracy: 0.971700
# Epoch: 4 (23.96 seconds) Train Loss: 0.045516 Train Accuracy: 0.986433 Test Loss: 0.241832 Test Accuracy: 0.971000
# Epoch: 5 (24.25 seconds) Train Loss: 0.045474 Train Accuracy: 0.986850 Test Loss: 0.239518 Test Accuracy: 0.972500
# Epoch: 6 (24.41 seconds) Train Loss: 0.045228 Train Accuracy: 0.986150 Test Loss: 0.229929 Test Accuracy: 0.970900
# Epoch: 7 (24.68 seconds) Train Loss: 0.045701 Train Accuracy: 0.985683 Test Loss: 0.269636 Test Accuracy: 0.970200
# Epoch: 8 (23.73 seconds) Train Loss: 0.045706 Train Accuracy: 0.985217 Test Loss: 0.252251 Test Accuracy: 0.969000
# Epoch: 9 (23.84 seconds) Train Loss: 0.041623 Train Accuracy: 0.987650 Test Loss: 0.252800 Test Accuracy: 0.972400
# Epoch: 10 (24.07 seconds) Train Loss: 0.039760 Train Accuracy: 0.987400 Test Loss: 0.211906 Test Accuracy: 0.973000
# Epoch: 11 (24.84 seconds) Train Loss: 0.039773 Train Accuracy: 0.988450 Test Loss: 0.276312 Test Accuracy: 0.970400
# Epoch: 12 (24.23 seconds) Train Loss: 0.035514 Train Accuracy: 0.989067 Test Loss: 0.267468 Test Accuracy: 0.971200
# Epoch: 13 (24.43 seconds) Train Loss: 0.038609 Train Accuracy: 0.988433 Test Loss: 0.330790 Test Accuracy: 0.969700
# Epoch: 14 (23.92 seconds) Train Loss: 0.045531 Train Accuracy: 0.986933 Test Loss: 0.285930 Test Accuracy: 0.969200
# Epoch: 15 (23.89 seconds) Train Loss: 0.035152 Train Accuracy: 0.989300 Test Loss: 0.270980 Test Accuracy: 0.973400
# Epoch: 16 (24.15 seconds) Train Loss: 0.044544 Train Accuracy: 0.988450 Test Loss: 0.362639 Test Accuracy: 0.970600
# Epoch: 17 (23.58 seconds) Train Loss: 0.040941 Train Accuracy: 0.987983 Test Loss: 0.352619 Test Accuracy: 0.970500
# Epoch: 18 (23.29 seconds) Train Loss: 0.033801 Train Accuracy: 0.988700 Test Loss: 0.277867 Test Accuracy: 0.971400
# Epoch: 19 (23.08 seconds) Train Loss: 0.044166 Train Accuracy: 0.985950 Test Loss: 0.283041 Test Accuracy: 0.967800
# Epoch: 20 (23.01 seconds) Train Loss: 0.042838 Train Accuracy: 0.986767 Test Loss: 0.298248 Test Accuracy: 0.969400
# Epoch: 21 (23.92 seconds) Train Loss: 0.036872 Train Accuracy: 0.988617 Test Loss: 0.318461 Test Accuracy: 0.970300
# Epoch: 22 (24.32 seconds) Train Loss: 0.040112 Train Accuracy: 0.987000 Test Loss: 0.306903 Test Accuracy: 0.967800
# Epoch: 23 (24.01 seconds) Train Loss: 0.037892 Train Accuracy: 0.989167 Test Loss: 0.388664 Test Accuracy: 0.971000
# Epoch: 24 (23.43 seconds) Train Loss: 0.043540 Train Accuracy: 0.988333 Test Loss: 0.364375 Test Accuracy: 0.971300
# Epoch: 25 (23.34 seconds) Train Loss: 0.036613 Train Accuracy: 0.988633 Test Loss: 0.300554 Test Accuracy: 0.969600
# Epoch: 26 (23.14 seconds) Train Loss: 0.040203 Train Accuracy: 0.987483 Test Loss: 0.351039 Test Accuracy: 0.969800
# Epoch: 27 (23.06 seconds) Train Loss: 0.038170 Train Accuracy: 0.988183 Test Loss: 0.327750 Test Accuracy: 0.969700
# Epoch: 28 (23.68 seconds) Train Loss: 0.035541 Train Accuracy: 0.989433 Test Loss: 0.344386 Test Accuracy: 0.969300
# Epoch: 29 (24.43 seconds) Train Loss: 0.039649 Train Accuracy: 0.988633 Test Loss: 0.333720 Test Accuracy: 0.969500
# Epoch: 30 (23.38 seconds) Train Loss: 0.042439 Train Accuracy: 0.986250 Test Loss: 0.329342 Test Accuracy: 0.968400
# Saving...
# Saved
# lenet model, took  714.71 seconds

# %%
######################################
# Loading Trained model              #
######################################
criterion = nn.CrossEntropyLoss().cuda()

train_model = LeNet()
prune_init_model(train_model)
init_params = random_init_model(train_model)

train_model.cuda()
model_name = model_dir + '/model_prune_lenet.pt'
train_model.load_state_dict(torch.load(model_name))

train_model.eval()
with torch.no_grad():
  test_loss, test_acc = EvaluateModel(train_model, criterion, test_loader)         
  print('Test Loss: {:.6f} Test Accuracy: {:.6f}'.format(test_loss, test_acc))
# Out:
# Test Loss: 0.354958 Test Accuracy: 0.908400

# %%
params = sum([np.prod(p.size()) for p in model.parameters()])
print(params)
# Out:
# 266610
